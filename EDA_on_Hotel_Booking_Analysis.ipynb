# %% [markdown]
# # **Project Name**    - EDA on Hotel Booking Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual/Team
# ##### **Team Member 1 - Mohamed Anees**
# ##### **Team Member 2 - Tanmay**
# ##### **Team Member 3 - Raghav Dadhich**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# In this Project we are provided with a Hotel Bookings Dataset. We are trying to help the client achieve their business objective by providing useful insights on this dataset.
#
# The following methods were used for creating the insights for our dataset:
#
#
# ###**Data cleaning and feature engineering :**
#
# All duplicate rows were dropped. Data type of children, company, agent to int type and data type of reservation_status_date to date type were created.
#
# ###**Exploratory Data Analysis:**
#
# We performed Exploratory Data Analysis to analyse the dataset provided to us and summarize their main characteristics.
#
# 1) Which agent makes the most no. of bookings?
#
# 2) Which room type is in most demand and which room type generatesthe  highest adr?
#
# 3) Which meal type isthe  most preffered meal of customers?
#
# 4) What isthe  percentage of bookings in each hotel?
#
# 5) Which is the most common channel for booking hotels?
#
# 6) Which are the most busy months?
#
# 7) From which country most of the guests are comin ?
#
# 8) How long do people stay at the hotels?
#
# 9)  Which hotel seems to make more revenue?
#
# 10)  Which hotel hasa  higher lead time?
#
# 11)  What is preferred stay length in each hotel?
#
# 12)  Which hotel has higher bookings cancellation rate?
#
# 13)  Which hotel hasa  high chance that its customer will return for another stay?
#
# 14)  Which channel is mostly used forthe  early booking of hotels?
#
# 15)  Which channel hasa  longer average waiting time?
#
# 16)  Which distribution channel brings betterrevenue-generatingg deals for hotels?
#
# 17)  Which significant distribution channel has the highest cancellation percentage?
#
# 18) Does a  longer waiting period or longer lead time causes the cancellation of bookings?
#
# 19) Whether not getting allotted the same room type as demand is the main cause of cancellation for bookings?
#
# 20) Does not alloting the  same room as demanded affect adr?
#
# 21) What is the trend of bookings within a month?
#
# 22) Which types of customers mostly make bookings?
#
#
# ###**Data Visualization :**
#
# We have used the following type of charts to represent the insights:
#
# 1) Bar Plot.
#
# 2) Histogram.
#
# 3) Pie Chart.
#
# 4) Line Plot.
#
# 5) Heatmap.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/MohamedAnees1995/CricStar

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special requests? This hotel booking dataset can help you explore those questions!**
#
# **This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data.**
#
# **Explore and analyze the data to discover important factors that govern the bookings.**

# %% [markdown]
# ![how-to-start-a-hotel.png](data:image/png;base64,...)

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# **We are provided with a hotel bookings dataset. Our main objective is to perform EDA on the given dataset and draw useful conclusions about general trends in hotel bookings and how factors governing hotel bookings interact with each other**.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import datetime as dat
import plotly.express as px

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset

from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
path = '/content/drive/My Drive/dat/'

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look

df = pd.read_csv(path + 'Hotel Bookings.csv')
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (119390, 32)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
#Check all the coloumns present in our dataset
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Creating a copy of our dataset

df1=df.copy()

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count

df1.duplicated().value_counts()   

# Returns boolean "true" if the data contains any duplicates.
# Out:
# False    87396
# True     31994
# dtype: int64

# %%
# Setting fontsizes,fontweight,label weight for labels,titles.
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams["axes.titlesize"] = 25
plt.rcParams["axes.titleweight"] = 'bold'
plt.rcParams['xtick.labelsize']=15
plt.rcParams['ytick.labelsize']=15
plt.rcParams["axes.labelsize"] = 20
plt.rcParams["legend.fontsize"] = 15
plt.rcParams["legend.title_fontsize"] = 15

# %%
# Visualizing through Countplot() method.
plt.figure(figsize=(10,8))
sns.countplot(x=df1.duplicated())

# %% [markdown]
# **Here we found 31994 duplicate rows in our data,so we will drop all duplicate rows from our data.**

# %%
#Dropping the duplicate rows
df1= df1.drop_duplicates()

# %%
# Data set reduced
df1.shape
# Out:
# (87396, 32)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df1.isna().sum()
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              4
# babies                                0
# meal                                  0
# country                             452
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# ...

# %%
df1.isna().sum().sort_values(ascending=False)
# Out:
# company                           82137
# agent                             12193
# country                             452
# children                              4
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# hotel                                 0
# previous_cancellations                0
# days_in_waiting_list                  0
# customer_type                         0
# adr                                   0
# required_car_parking_spaces           0
# total_of_special_requests             0
# reservation_status                    0
# previous_bookings_not_canceled        0
# is_repeated_guest                     0
# is_canceled                           0
# distribution_channel                  0
# market_segment                        0
# meal                                  0
# babies                                0
# ...

# %%
print(df.isnull().values.sum())
# Out:
# 129425

# %%
df1.isna().sum().sort_values(ascending=False)[:6].reset_index()
# Out:
#                 index      0
# 0             company  82137
# 1               agent  12193
# 2             country    452
# 3            children      4
# 4  reserved_room_type      0
# 5  assigned_room_type      0

# %%
df1.isna().sum().sort_values(ascending=False)[:6].reset_index().rename(columns={'index':'Columns',0:'Null values'})
# Out:
#               Columns  Null values
# 0             company        82137
# 1               agent        12193
# 2             country          452
# 3            children            4
# 4  reserved_room_type            0
# 5  assigned_room_type            0

# %%
# Visualizing the missing values

plt.figure(figsize=(25, 10))
sns.heatmap(df1.isnull(), cbar=False, yticklabels=False,cmap='plasma')
plt.xlabel("Name Of Columns")
plt.title("Places of missing values in column")
# Out:
# Text(0.5, 1.0, 'Places of missing values in column')

# %% [markdown]
# # **Finally we detected Null-Values in columns - company,agent,country,children**
#
# **1.Here we will fill three columns with 0 instead of null values namely 'Company', 'Agent', 'Children'.**
#
# **2.For 'country' we will fill Missing values with object 'Others'.**

# %%
# Replacing null values with 0.

null_columns=['agent','children','company']
for col in null_columns:
    df1[col].fillna(0,inplace=True)


# Replacing null values with 'Others'

df1['country'].fillna('Others',inplace=True)

# %%
df1.isna().sum().sort_values(ascending=False)[:6].reset_index().rename(columns={'index':'Columns',0:'Null values'})
# Out:
#                        Columns  Null values
# 0                        hotel            0
# 1                  is_canceled            0
# 2           reservation_status            0
# 3    total_of_special_requests            0
# 4  required_car_parking_spaces            0
# 5                          adr            0

# %% [markdown]
# ### **What did you know about your dataset?**
#
# We are given a hotel bookings dataset. This dataset contains booking information for a city hotel and a resort hotel. It contains the following features.
#
# - hotel: Name of hotel ( City or Resort)
# - is_canceled: Whether the booking is canceled or not (0 for not cancelled and 1 for cancelled)
# - lead_time: time (in days) between booking transaction and actual arrival.
# - arrival_date_year: Year of arrival
# - arrival_date_month: month of arrival
# - arrival_date_week_number: week number of arrival date.
# - arrival_date_day_of_month: Day of month of arrival date
# - stays_in_weekend_nights: No. of weekend nights spent in a hotel
# - stays_in_week_nights: No. of weeknights spent in a hotel
# - adults: No. of adults in single booking record.
# - children: No. of children in single booking record.
# - babies: No. of babies in single booking record.
# - meal: Type of meal chosen
# - country: Country of origin of customers (as mentioned by them)
# - market_segment: What segment via booking was made and for what purpose.
# - distribution_channel: Via which medium booking was made.
# - is_repeated_guest: Whether the customer has made any booking before(0 for No and 1 for Yes)
# - previous_cancellations: No. of previous canceled bookings.
# - previous_bookings_not_canceled: No. of previous non-canceled bookings.
# - reserved_room_type: Room type reserved by a customer.
# - assigned_room_type: Room type assigned to the customer.
# - booking_changes: No. of booking changes done by customers
# - deposit_type: Type of deposit at the time of making a booking (No deposit/ Refundable/ No refund)
# - agent: Id of agent for booking
# - company: Id of the company making a booking
# - days_in_waiting_list: No. of days on waiting list.
# - customer_type: Type of customer(Transient, Group, etc.)
# - adr: Average Daily rate.
# - required_car_parking_spaces: No. of car parking asked in booking
# - total_of_special_requests: total no. of special request.
# - reservation_status: Whether a customer has checked out or canceled,or not showed
# - reservation_status_date: Date of making reservation status.
#
# Total number of rows in data: 119390
# Total number of columns: 32

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns

df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe

df.describe(include='all')
# Out:
#              hotel    is_canceled      lead_time  arrival_date_year  \
# count       119390  119390.000000  119390.000000      119390.000000
# unique           2            NaN            NaN                NaN
# top     City Hotel            NaN            NaN                NaN
# freq         79330            NaN            NaN                NaN
# mean           NaN       0.370416     104.011416        2016.156554
# std            NaN       0.482918     106.863097           0.707476
# min            NaN       0.000000       0.000000        2015.000000
# 25%            NaN       0.000000      18.000000        2016.000000
# 50%            NaN       0.000000      69.000000        2016.000000
# 75%            NaN       1.000000     160.000000        2017.000000
# max            NaN       1.000000     737.000000        2017.000000
#
#        arrival_date_month  arrival_date_week_number  \
# count              119390             119390.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# **We are given a hotel bookings dataset. This dataset contains booking information for a city hotel and a resort hotel. It contains the following features**.
#
# - hotel: Name of hotel ( City or Resort)
# - is_canceled: Whether the booking is canceled or not (0 for not cancelled and 1 for cancelled)
# - lead_time: time (in days) between booking transaction and actual arrival.
# - arrival_date_year: Year of arrival
# - arrival_date_month: month of arrival
# - arrival_date_week_number: week number of arrival date.
# - arrival_date_day_of_month: Day of month of arrival date
# - stays_in_weekend_nights: No. of weekend nights spent in a hotel
# - stays_in_week_nights: No. of weeknights spent in a hotel
# - adults: No. of adults in single booking record.
# - children: No. of children in single booking record.
# - babies: No. of babies in single booking record.
# - meal: Type of meal chosen
# - country: Country of origin of customers (as mentioned by them)
# - market_segment: What segment via booking was made and for what purpose.
# - distribution_channel: Via which medium booking was made.
# - is_repeated_guest: Whether the customer has made any booking before(0 for No and 1 for Yes)
# - previous_cancellations: No. of previous canceled bookings.
# - previous_bookings_not_canceled: No. of previous non-canceled bookings.
# - reserved_room_type: Room type reserved by a customer.
# - assigned_room_type: Room type assigned to the customer.
# - booking_changes: No. of booking changes done by customers
# - deposit_type: Type of deposit at the time of making a booking (No deposit/ Refundable/ No refund)
# - agent: Id of agent for booking
# - company: Id of the company making a booking
# - days_in_waiting_list: No. of days on waiting list.
# - customer_type: Type of customer(Transient, Group, etc.)
# - adr: Average Daily rate.
# - required_car_parking_spaces: No. of car parking asked in booking
# - total_of_special_requests: total no. of special request.
# - reservation_status: Whether a customer has checked out or canceled,or not showed
# - reservation_status_date: Date of making reservation status.
#
# **Total number of rows in data: 119390**
#
#   **Total number of columns: 32**

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df1['hotel'].unique()
# Out:
# array(['Resort Hotel', 'City Hotel'], dtype=object)

# %%
df1['is_canceled'].unique()
# Out:
# array([0, 1])

# %%
df1['arrival_date_year'].unique()
# Out:
# array([2015, 2016, 2017])

# %%
df1['meal'].unique()
# Out:
# array(['BB', 'FB', 'HB', 'SC', 'Undefined'], dtype=object)

# %%
df1['market_segment'].unique()
# Out:
# array(['Direct', 'Corporate', 'Online TA', 'Offline TA/TO',
#        'Complementary', 'Groups', 'Undefined', 'Aviation'], dtype=object)

# %%
df1['distribution_channel'].unique()
# Out:
# array(['Direct', 'Corporate', 'TA/TO', 'Undefined', 'GDS'], dtype=object)

# %%
df1['children'].unique()   

# This column has 0 as well as null values
# Out:
# array([ 0.,  1.,  2., 10.,  3.])

# %%
df1['reserved_room_type'].unique()
# Out:
# array(['C', 'A', 'D', 'E', 'G', 'F', 'H', 'L', 'P', 'B'], dtype=object)

# %%
df1['assigned_room_type'].unique()
# Out:
# array(['C', 'A', 'D', 'E', 'G', 'F', 'I', 'B', 'H', 'P', 'L', 'K'],
#       dtype=object)

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87396 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           87396 non-null  object
#  1   is_canceled                     87396 non-null  int64
#  2   lead_time                       87396 non-null  int64
#  3   arrival_date_year               87396 non-null  int64
#  4   arrival_date_month              87396 non-null  object
#  5   arrival_date_week_number        87396 non-null  int64
#  6   arrival_date_day_of_month       87396 non-null  int64
#  7   stays_in_weekend_nights         87396 non-null  int64
#  8   stays_in_week_nights            87396 non-null  int64
#  9   adults                          87396 non-null  int64
#  10  children                        87396 non-null  float64
#  11  babies                          87396 non-null  int64
# ...

# %%
# Converting datatype to save size

df1['hotel']=df1['hotel'].astype('category')
df1['meal']=df1['meal'].astype('category')
df1['market_segment']=df1['market_segment'].astype('category')
df1['distribution_channel']=df1['distribution_channel'].astype('category')
df1['reserved_room_type']=df1['reserved_room_type'].astype('category')
df1['assigned_room_type']=df1['assigned_room_type'].astype('category')
df1['customer_type']=df1['customer_type'].astype('category')
df1['reservation_status']=df1['reservation_status'].astype('category')

# Converting datatype of columns 'children', 'company' and 'agent' from float to int.

df1[['children', 'company', 'agent']] = df1[['children', 'company', 'agent']].astype('int64')


# Converting object type to datetime

df1['reservation_status_date'] = pd.to_datetime(df1['reservation_status_date'], format = '%Y-%m-%d')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87396 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           87396 non-null  category
#  1   is_canceled                     87396 non-null  int64
#  2   lead_time                       87396 non-null  int64
#  3   arrival_date_year               87396 non-null  int64
#  4   arrival_date_month              87396 non-null  object
#  5   arrival_date_week_number        87396 non-null  int64
#  6   arrival_date_day_of_month       87396 non-null  int64
#  7   stays_in_weekend_nights         87396 non-null  int64
#  8   stays_in_week_nights            87396 non-null  int64
#  9   adults                          87396 non-null  int64
#  10  children                        87396 non-null  int64
#  11  babies                          87396 non-null  int64
# ...

# %%
df1.sort_values('adults',ascending=True).head(5)
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 103264  City Hotel            0          0               2016
# 71667   City Hotel            1        340               2017
# 47166   City Hotel            1          1               2016
# 52156   City Hotel            0        150               2016
# 65907   City Hotel            1          0               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 103264           December                        52
# 71667                July                        28
# 47166            February                         7
# 52156                 May                        23
# 65907               April                        15
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 103264                         18                        0
# 71667                           9                        2
# 47166                          11                        0
# ...

# %%
len(df1[df1['adults']+df1['babies']+df1['children']==0])
# Out:
# 166

# %% [markdown]
# **Dropping all 166 of those rows in which addtion ofadults ,children and babies is 0. That simply means  no bookings were made**.

# %%
df1.drop(df1[df1['adults']+df1['babies']+df1['children']==0].index,inplace=True)

# %%
# Adding important columns

df1['total_number_of_people'] = df1['adults'] + df1['babies'] + df1['children']   
df1['total_stays'] = df1['stays_in_weekend_nights'] + df1['stays_in_week_nights']

# %%
df1.shape
# Out:
# (87230, 34)

# %% [markdown]
# ### **What all manipulations have you done and insights you found?**

# %% [markdown]
# ####**(1) Removing Duplicate rows**
#
# All duplicate rows were dropped.
#
# ####**(2) Handling null values**
#
# Null values in columns company and agent were replaced by 0.
# Null values in column country were replaced by 'others'.
# Null values in column children were replaced by the mean of the column.
#
# ####**(3) Converting columns to appropriate data types**
#
# Changed data type of hotel, meal, market_segment, distribution_channel, reserved_room_type, assigned_room_type, customer_type to **category** type.
#
# Changed data type of children, company, agent to **int** type.
#
# Changed data type of reservation_status_date to **datetime** type.
#
# ####**(4) Removing outliers**
#
# One outlier was found in the adr column. Simply dropped it.
#
# ####**(5) Creating new columns**
#
# Created new column **total_stays** by adding **stays_in_weekend_nights** +  **stays_in_week_nights**.
#
# Created new column **total_people** by adding **adults** + **children** + **babies**.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #Univariate Analysis

# %% [markdown]
# #### **Chart - 1**

# %% [markdown]
# ###**Which type of hotel do guests prefer the most?**

# %%
# Chart - 1 visualization code

df1['hotel'].value_counts().plot.pie(explode=[0.02, 0.02], autopct='%1.1f%%', shadow=True, figsize=(10,8),fontsize=20)
plt.title("Pie Chart For Most Preffered Hotel")
# Out:
# Text(0.5, 1.0, 'Pie Chart For Most Preffered Hotel')

# %% [markdown]
# #### **1. Why did you pick the specific chart?**

# %% [markdown]
# A pie chart helps organize and show data as a percentage of a whole.

# %% [markdown]
# #### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# City Hotel is the most preferred hotel among guests. So there are maximum bookings in city hotels.

# %% [markdown]
# #### **3. Will the gained insights help creating a positive business impact?**
# **Are there any insights that lead to negative growth? Justify with specific reason.**

# %% [markdown]
# Yes it will surely help in creating a positive business impact since it shows that majority of people prefer city Hotels.

# %% [markdown]
# ###**2) Which agent made the most bookings?**

# %% [markdown]
# #### **Chart - 2**

# %%
# Chart - 2 visualization code

# Counting highest bookings made by agents

highest_bookings= df1.groupby(['agent'])['agent'].agg({'count'}).reset_index().rename(columns={'count': "Most_Bookings" }).sort_values(by='Most_Bookings',ascending=False)

# %%
highest_bookings
# Out:
#      agent  Most_Bookings
# 9        9          28721
# 174    240          13028
# 0        0          12141
# 14      14           3342
# 7        7           3294
# ..     ...            ...
# 194    267              1
# 65      73              1
# 251    352              1
# 193    265              1
# 300    446              1
#
# [334 rows x 2 columns]

# %%
len(highest_bookings[highest_bookings['agent']==0].index)
# Out:
# 1

# %%
# If the booking count shows a value of 0, it means there are no bookings. So let's drop those values from the data.

highest_bookings.drop(highest_bookings[highest_bookings['agent']==0].index,inplace=True)

# %%
# Taking top 10 bookings made by agent

top_ten_highest_bookings=highest_bookings[:10]

top_ten_highest_bookings
# Out:
#      agent  Most_Bookings
# 9        9          28721
# 174    240          13028
# 14      14           3342
# 7        7           3294
# 183    250           2779
# 175    241           1644
# 27      28           1493
# 8        8           1383
# 1        1           1228
# 6        6           1117

# %%
# Visualizing the graph

plt.figure(figsize=(18,8))
sns.barplot(x=top_ten_highest_bookings['agent'],y=top_ten_highest_bookings['Most_Bookings'],order=top_ten_highest_bookings['agent'],palette="plasma")
plt.xlabel('Agent_No')
plt.ylabel('Number_Of_Bookings')
plt.title("Most Bookings Made by the agent")
# Out:
# Text(0.5, 1.0, 'Most Bookings Made by the agent')

# %% [markdown]
# #### **1. Why did you pick the specific chart?**

# %% [markdown]
# The Bar Graph is used to show the relationship using two axes, in which the **Number_of_bookings** are on one axis and **Agent_No** are on the other axis.

# %% [markdown]
# #### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# The agent with ID number: **9** has made the highest number of bookings.

# %% [markdown]
# #### **3. Will the gained insights help creating a positive business impact?**
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights will surely help in creating a positive business impact.

# %% [markdown]
# ###**What is the cancellation percentage of bookings?**

# %% [markdown]
# #### **Chart - 3**

# %%
# Chart - 3 visualization code

df1['is_canceled'].value_counts().plot.pie(explode=[0.02,0.02],autopct="%1.1f%%",shadow=True,figsize=(10,8),fontsize=20)
plt.title("Cancellation(1) & Non_Cancellation(0) Of Bookings")
# Out:
# Text(0.5, 1.0, 'Cancellation(1) & Non_Cancellation(0) Of Bookings')

# %% [markdown]
# ### **1. Why did you pick the specific chart?**

# %% [markdown]
# A pie chart helps organize and show data as a percentage of a whole.

# %% [markdown]
# ### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# 27.5% of the bookings were cancelled.

# %% [markdown]
# ### **3. Will the gained insights help creating a positive business impact?**
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights will surely help in creating a positive business as it shows that more than 70% bookings were not cancelled.

# %% [markdown]
# ###**4) What is the Percentage of repeated guests?**

# %% [markdown]
# #### **Chart - 4**

# %%
# Chart - 4 visualization code

df1['is_repeated_guest'].value_counts().plot.pie(explode=[0.1,0.1],autopct='%1.1f%%',shadow=True,colors=['#36EF4F','#Ef3636'],figsize=(12,8),fontsize=20)
plt.title("Percentage Of Repeated Guests(1)")
# Out:
# Text(0.5, 1.0, 'Percentage Of Repeated Guests(1)')

# %% [markdown]
# ### **1. Why did you pick the specific chart?**

# %% [markdown]
# A pie chart helps organize and show data as a percentage of a whole.

# %% [markdown]
# ### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# Repeated guests are only 3.9%, so to retain the guests, it is important to take feedback from them, with the help of these feedbacks hotel management should make some improvements according to the guest needs and provide services to reach the guests.

# %% [markdown]
# ### **3. Will the gained insights help creating a positive business impact?**
# ###**Are there any insights that lead to negative growth? Justify with specific reason**.

# %% [markdown]
# ####The following insight shows us that the percentage of repeated guests is very low which leads to negative growth.
#
#
# ####This can be improved with the help of following factors :
#
#
#
#
#
# **1. Create a Loyalty Program.**
#
# **2. Provide Excellent Customer Service.**
#
# **3. Focus on Cleanliness.**
#
# **4. Offer Value-Added Amenities.**
#
# **5. Utilize Social Media.**
#
# **6. Ask for Feedback.**
#
# **7. Follow Up.**

# %% [markdown]
# ###**5) What is the percentage distribution of "Customer Type"?**

# %% [markdown]
# #### **Chart - 5**

# %%
# Chart - 5 visualization code

df1['customer_type'].value_counts().plot.pie(explode=[0.05,0.05,0.05,0.05],colors=['#3671ef','#36efdc','#52ef36','#d336ef'],shadow=True,autopct='%1.1f%%',figsize=(12,8),fontsize=15,labels=None)

labels=df1['customer_type'].value_counts().index.tolist()
plt.title('Percentage Distribution of Customer Type')
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=labels)

# %% [markdown]
# ### **1. Why did you pick the specific chart?**

# %% [markdown]
# A pie chart helps organize and show data as a percentage of a whole.

# %% [markdown]
# ### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# Transient Customer_Type is Distributed more which is 82.4% and percentage of booking associated with group(0.6%) is very low.

# %% [markdown]
# ### **3. Will the gained insights help creating a positive business impact?**
# ###**Are there any insights that lead to negative growth? Justify with specific reason.**

# %% [markdown]
# The gained insights will surely help in creating a positive business impact.

# %% [markdown]
# ###**6)What is the percentage distribution of required_car_parking_spaces?**

# %% [markdown]
# #### **Chart - 6**

# %%
# Chart - 6 visualization code

df1['required_car_parking_spaces'].value_counts().plot.pie(explode=[0.05]*5,colors=['#3671ef','#efe336','#36efdc','#52ef36','#d336ef'], autopct='%1.1f%%',shadow=False,figsize=(12,8),fontsize=15,labels=None)

labels=df1['required_car_parking_spaces'].value_counts().index
plt.title('Percentage Distribution of required car parking spaces')
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=labels)

# %% [markdown]
# ###**1. Why did you pick the specific chart?**

# %% [markdown]
# A pie chart helps organize and show data as a percentage of a whole.

# %% [markdown]
# ###**2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# 91.6 % guests did not required the parking space. only 8.3 % guests required only 1 parking space.

# %% [markdown]
# ###**3. Will the gained insights help creating a positive business impact?**
# ###**Are there any insights that lead to negative growth? Justify with specific reason.**

# %% [markdown]
# This shows that the parking space provided is sufficient for majority of the guests that is over 90%.

# %% [markdown]
# ###**7)What is the percentage of booking changes made by the customer.?**

# %% [markdown]
# #### **Chart - 7**

# %%
# Chart - 7 visualization code

booking_changes_df=df1['booking_changes'].value_counts()
booking_changes_df
# Out:
# 0     71425
# 1     10868
# 2      3483
# 3       862
# 4       347
# 5       113
# 6        57
# 7        29
# 8        14
# 9         8
# 10        6
# 13        5
# 14        3
# 15        3
# 17        2
# 16        2
# 12        1
# 18        1
# 11        1
# Name: booking_changes, dtype: int64

# %%
booking_changes_df=df1['booking_changes'].value_counts().reset_index().rename(columns={'index': "number_booking_changes",'booking_changes':'Counts'})
booking_changes_df
# Out:
#     number_booking_changes  Counts
# 0                        0   71425
# 1                        1   10868
# 2                        2    3483
# 3                        3     862
# 4                        4     347
# 5                        5     113
# 6                        6      57
# 7                        7      29
# 8                        8      14
# 9                        9       8
# 10                      10       6
# 11                      13       5
# 12                      14       3
# 13                      15       3
# 14                      17       2
# 15                      16       2
# 16                      12       1
# 17                      18       1
# 18                      11       1

# %%
# Visualizing 

plt.figure(figsize=(12,8))

#Sum(booking_changes_df['Counts'] OR df1.shape[0] to convert count values into percentages. 

sns.barplot(x=booking_changes_df['number_booking_changes'],y=booking_changes_df['Counts']*100/sum(booking_changes_df['Counts']),palette='prism')
plt.title("Percentage of Booking change")
plt.xlabel('Number of booking changes')
plt.ylabel('Percentage(%)')
# Out:
# Text(0, 0.5, 'Percentage(%)')

# %% [markdown]
# ###0= 0 changes made in the booking
#
# ###1= 1 changes made in the booking
#
# ###2= 2 changes made in the booking

# %% [markdown]
# ### **1. Why did you pick the specific chart?**

# %% [markdown]
# It shows the relationship using two axes, in which the **Percentages(%**) are on one axis and **Number of booking changes** are on the other axis.

# %% [markdown]
# ### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# Almost 82% of the bookings were not changed by guests.

# %% [markdown]
# ### **3. Will the gained insights help creating a positive business impact?**
# ###**Are there any insights that lead to negative growth? Justify with specific reason.**

# %% [markdown]
# The gained insights will surely help in creating a positive business impact because 82% of the bookings were not changed by the guests.

# %% [markdown]
# ###**8)What is The Percentage Distribution of Deposite type ?**

# %% [markdown]
# #### **Chart - 8**

# %%
# Chart - 8 visualization code

df1['deposit_type'].value_counts().plot.pie(explode=(0.5,0.5,0.05),colors=['#3671ef','#45ef36','#ef3636'],autopct='%1.1f%%',shadow=True,figsize=(14,8),fontsize=20,labels=None)
plt.title("Percentage Distribution of deposit type")
labels=df1['deposit_type'].value_counts().index.tolist()
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=labels)

# %% [markdown]
# ### **1. Why did you pick the specific chart?**

# %% [markdown]
# A pie chart helps organize and show data as a percentage of a whole.

# %% [markdown]
# ### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# 98.7 % of guests prefer "No Deposit" type of deposit.

# %% [markdown]
# ### **3. Will the gained insights help creating a positive business impact?**
# **Are there any insights that lead to negative growth? Justify with specific reason.**

# %% [markdown]
# Yes it will help in creating a positive business impact because it shows that 98.7% guests prefer **no deposit** type of **deposit.**

# %% [markdown]
# ###**9) Which type of food is mostly preferred by the guests?**

# %% [markdown]
# #### **Chart - 9**

# %%
# Chart - 9 visualization code

plt.figure(figsize=(18,8))
sns.countplot(x=df1['meal'],palette='gist_ncar')
plt.xlabel('Meal Type')
plt.ylabel('Count')
plt.title("Preferred Meal Type")
# Out:
# Text(0.5, 1.0, 'Preferred Meal Type')

# %% [markdown]
# ### **1. Why did you pick the specific chart?**

# %% [markdown]
# It shows the relationship using two axes, in which the **Count** is on one axis and **Meal Type** is on the other axis.

# %% [markdown]
# ### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# 1.So the most preferred meal type by the guests is **BB( Bed and Breakfast).**
#
# 2.**HB- (Half Board)** and **SC- (Self Catering)** are equally preferred.

# %% [markdown]
# ### **3. Will the gained insights help creating a positive business impact?**
# ###**Are there any insights that lead to negative growth? Justify with specific reason.**

# %% [markdown]
# This will surely help in creating a positive business impact since most preferred meal type is **BB(Bed and Breakfast)** but it also has **HB(Half Board)** and **SC(Self Catering)** as the second most preffered meal type. This shows other meal types are also in demand along with **BB(Bed and Breakfast)** type of meal.

# %% [markdown]
# ###**10) From which country the most guests are coming?**

# %% [markdown]
# #### **Chart - 10**

# %%
# Chart - 10 visualization code

# Counting the guests from various countries.
country_df=df1['country'].value_counts().reset_index()
country_df
# Out:
#     index  country
# 0     PRT    27355
# 1     GBR    10424
# 2     FRA     8823
# 3     ESP     7244
# 4     DEU     5385
# ..    ...      ...
# 173   MMR        1
# 174   BFA        1
# 175   CYM        1
# 176   MLI        1
# 177   KHM        1
#
# [178 rows x 2 columns]

# %%
# Selecting  top 15 countries

country_df = country_df.rename(columns={'index': 'country','country': 'count of guests'})[:15]
country_df
# Out:
#    country  count of guests
# 0      PRT            27355
# 1      GBR            10424
# 2      FRA             8823
# 3      ESP             7244
# 4      DEU             5385
# 5      ITA             3061
# 6      IRL             3015
# 7      BEL             2081
# 8      BRA             1993
# 9      NLD             1910
# 10     USA             1871
# 11     CHE             1566
# 12      CN             1093
# 13     AUT              947
# 14     SWE              833

# %%
# Visualizing by  plotting the bar graph.

plt.figure(figsize=(20,8))
sns.barplot(x=country_df['country'],y=country_df['count of guests'],palette='gist_rainbow')
plt.xlabel('Country')
plt.ylabel('Number of guests',fontsize=12)
plt.title("Number of guests from diffrent Countries")
# Out:
# Text(0.5, 1.0, 'Number of guests from diffrent Countries')

# %% [markdown]
# ### **1. Why did you pick the specific chart?**

# %% [markdown]
# It shows the relationship using two axes, in which the Number of guests are on one axis and their countries are on the other axis.

# %% [markdown]
# ####**Abbreviations for countries-**
#
# PRT - Portugal
#
# GBR - United Kingdom
#
# FRA - France
#
# ESP - Spain
#
# DEU - Germany
#
# ITA - Italy
#
# IRL - Ireland
#
# BEL - Belgium
#
# BRA - Brazil
#
# NLD - Netherlands
#
# USA - United States Of America
#
# CHE - Switzerland
#
# CN - China
#
# AUT - Australia
#
# SWE-Sweden

# %% [markdown]
# ### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# Most of the guests are coming from portugal i.e more then 25000 guests are from portugal.

# %% [markdown]
# ### **3. Will the gained insights help creating a positive business impact?**
# ###**Are there any insights that lead to negative growth? Justify with specific reason.**

# %% [markdown]
# The gained insights will surely help in creating a positive business impact. The fact that majority of the guests are from Europe only shows that it has failed to attract guests from other continents.

# %% [markdown]
# ###**11) Which is the most preferred room type by the customers?**

# %% [markdown]
# ### **Chart - 11**

# %%
# Chart - 11 visualization code

plt.figure(figsize=(18,8))
sns.countplot(x=df1['assigned_room_type'],order=df1['assigned_room_type'].value_counts().index,palette='gist_earth')
plt.xlabel('assigned_room_type')
plt.ylabel('Count_of_room_type')
plt.title("Most Preferred Room Type")
# Out:
# Text(0.5, 1.0, 'Most Preferred Room Type')

# %% [markdown]
# #### **1. Why did you pick the specific chart?**

# %% [markdown]
# It shows the relationship using two axes, in which the **count_of_room_type** is on one axis and **assigned_room_type** is on the other axis.

# %% [markdown]
# #### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# Mostly guests prefer to stay in the room type"A"

# %% [markdown]
# #### **3. Will the gained insights help creating a positive business impact?**
# ####**Are there any insights that lead to negative growth? Justify with specific reason.**

# %% [markdown]
# The gained insights will surely help in creating a positive business impact.

# %% [markdown]
# ###**12) In which month most of the bookings happened?**

# %% [markdown]
# ###**Chart - 12**

# %%
# Chart - 12 visualization code

# Groupby arrival_date_month and taking the hotel count

arrival_date_month_df=df1.groupby(['arrival_date_month'])['hotel'].count().reset_index().rename(columns={'hotel':"Counts"})
arrival_date_month_df
# Out:
#    arrival_date_month  Counts
# 0               April    7900
# 1              August   11242
# 2            December    5112
# 3            February    6083
# 4             January    4685
# 5                July   10043
# 6                June    7756
# 7               March    7489
# 8                 May    8344
# 9            November    4973
# 10            October    6921
# 11          September    6682

# %%
# Create list of months in order

months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# Creating DataFrame, which will map the order of above months list without changing its values.

arrival_date_month_df['arrival_date_month']=pd.Categorical(arrival_date_month_df['arrival_date_month'],categories=months,ordered=True)

# Sorting by arrival_date_month

arrival_date_month_df=arrival_date_month_df.sort_values('arrival_date_month')

arrival_date_month_df
# Out:
#    arrival_date_month  Counts
# 4             January    4685
# 3            February    6083
# 7               March    7489
# 0               April    7900
# 8                 May    8344
# 6                June    7756
# 5                July   10043
# 1              August   11242
# 11          September    6682
# 10            October    6921
# 9            November    4973
# 2            December    5112

# %%
## Visualizing the Data

plt.figure(figsize=(20,8))
sns.lineplot(x=arrival_date_month_df['arrival_date_month'],y=arrival_date_month_df['Counts'],linewidth=5,palette='Blues')
plt.xlabel('Months')
plt.ylabel('Number_Of_Bookings')
plt.title('Total Number Of Bookings Across Each Month')
# Out:
# Text(0.5, 1.0, 'Total Number Of Bookings Across Each Month')

# %% [markdown]
# ####**1. Why did you pick the specific chart?**

# %% [markdown]
# lineplot() function helps to represent the multi data variable relationships with a varying size of line to be plotted.

# %% [markdown]
# ####**2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# The graph rose exponentially from early June, peaking in late July. It then falls very deep between August and September. July and August months had the most Bookings why because Summer vaccation may be the reason for the bookings.
#
#
#
# 5 Ways to get more to booking during the monsoon, winter, autumn seasons :
#
#
#
# 1. **Offer Special Deals and Discounts.**
#
#
# 2. **Utilize Social Media.**
#
#
# 3. **Create Special Packages.**
#
#
# 4. **Leverage Local Events.**
#
#
# 5. **Focus on Customer Service.**

# %% [markdown]
# ####**3. Will the gained insights help creating a positive business impact?**
# ####**Are there any insights that lead to negative growth? Justify with specific reason.**

# %% [markdown]
# The insights will help in creating a positive business impact as it shows the increase in the total no of booking in July and August which means it is a peak month for bookings.

# %% [markdown]
# ####**13) Which Distribution channel is mostly used for hotel bookings?**

# %% [markdown]
# ####**Chart - 13**

# %%
# Chart - 13 visualization code

# Creating new DataFrame of distribution channel

distribution_channel_df=df1['distribution_channel'].value_counts().reset_index().rename(columns={'index':"distribution_channel",'distribution_channel':'count'})
distribution_channel_df
# Out:
#   distribution_channel  count
# 0                TA/TO  69028
# 1               Direct  12954
# 2            Corporate   5062
# 3                  GDS    181
# 4            Undefined      5

# %%
## Visualizing the Data

labels_1 = df1['distribution_channel'].value_counts().index.tolist()
distribution_channel_df['percentage'] = round(distribution_channel_df['count']*100/df1.shape[0],2)
sizes = distribution_channel_df['percentage'].values.tolist()
labels_2 = [f'{l},{s}%' for l,s in zip(labels_1,sizes)]
df1['distribution_channel'].value_counts().plot.pie(explode=[0.05, 0.05,0.05,0.05,0.05], colors=['#369cef','#36efd6','#b8ef36','#ef3636','#efbe36'],shadow=True, figsize=(15,8),fontsize=10,labels=None)
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=labels_2)
plt.title(' Mostly Used Distribution Channel for Hotel Bookings ')
# Out:
# Text(0.5, 1.0, ' Mostly Used Distribution Channel for Hotel Bookings ')

# %% [markdown]
# #### **1. Why did you pick the specific chart?**

# %% [markdown]
# A pie chart helps organize and show data as a percentage of a whole.

# %% [markdown]
# #### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# 'TA/TO' is mostly(79.1%) used for booking hotels.

# %% [markdown]
# #### **3. Will the gained insights help creating a positive business impact?**
# ####**Are there any insights that lead to negative growth? Justify with specific reason.**

# %% [markdown]
# The gained insights will help in creating a positive business impact as it shows most people used **"TA/TO"** distribution channel which means people look to plan early for their visit using this distribution channel.

# %% [markdown]
# ####**14) Which year had the highest bookings?**

# %% [markdown]
# ####**Chart - 14**

# %%
# Chart - 14 visualization code

# Set plot size

plt.figure(figsize=(12,8))

# Plot with countplot

sns.countplot(x=df1['arrival_date_year'],hue=df1['hotel'],palette='Accent')
plt.title("Year Wise bookings")
# Out:
# Text(0.5, 1.0, 'Year Wise bookings')

# %% [markdown]
# #### **1. Why did you pick the specific chart?**

# %% [markdown]
# It shows the relationship using two axes, in which the **count** is on one axis and **arrival_date_year** is on the other axis.

# %% [markdown]
# #### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# 1. **2016 had the higest bookings.**
#
# 2. **2015 had the least bookings.**
#
# 3.   Overall **City hotels** had most of the bookings.
#
# 5 Ways to Get More Guests to Resort Hotels Compared to City Hotels.
#
# 1. **Offer deals and discounts for resort hotels.**
#
#
# 2. **Promote the unique benefits of resort hotels.**
#
#
#
# 3. **Focus on local guests.**
#
#
#
# 4. **Utilize online marketing.**
#
#
#
# 5. **Offer packages and add-ons.**

# %% [markdown]
# #### **3. Will the gained insights help creating a positive business impact?**
# ####**Are there any insights that lead to negative growth? Justify with specific reason.**

# %% [markdown]
# The gained insights will surely help in creating a positive business impact.

# %% [markdown]
# #Bivariate And Multivariate Analysis.

# %% [markdown]
# ####**1) Which Hotel type has the highest ADR(Average Daily Rate)?**

# %% [markdown]
# ####**Chart - 1**

# %%
# Chart - 1 visualization code

highest_adr = df1.groupby('hotel')['adr'].mean().reset_index()
highest_adr
# Out:
#           hotel         adr
# 0    City Hotel  111.271969
# 1  Resort Hotel   99.059517

# %%
# Set plot size

plt.figure(figsize=(10,8))

# Plot the graph

sns.barplot(x=highest_adr['hotel'],y=highest_adr['adr'],palette='summer')

# Set labels

plt.xlabel('Hotel')
plt.ylabel('ADR')
plt.title("Avg ADR Of Each Hotel type")
# Out:
# Text(0.5, 1.0, 'Avg ADR Of Each Hotel type')

# %% [markdown]
# #### **1. Why did you pick the specific chart?**

# %% [markdown]
# It shows the relationship using two axes, in which the **ADR** is on one axis and **Hotel** is on the other axis.

# %% [markdown]
# #### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# **ADR(Average Daily Rate) = [Total Revenues generated by all the occupied rooms in a hotel or lodge / Total number of rooms occupied over a given time period]**
#
# 1. ADR is directly proportional to revenue, so if average adr increases, revenue will automatically increase.
#
# 2. City hotel has the highest ADR. That means city hotels are generating more revenues than the resort hotels.

# %% [markdown]
# #### **3. Will the gained insights help creating a positive business impact?**
# ####**Are there any insights that lead to negative growth? Justify with specific reason.**

# %% [markdown]
# The gained insights will surely help in creating a positive business impact.

# %% [markdown]
# ####**2) Which hotel type has the more lead time?**

# %% [markdown]
# ####**Chart - 2**

# %%
# Chart - 2 visualization code

avg_lead_time = df1.groupby('hotel')['lead_time'].mean().reset_index()
avg_lead_time
# Out:
#           hotel  lead_time
# 0    City Hotel  77.793257
# 1  Resort Hotel  83.387737

# %%
# Set plot size

plt.figure(figsize=(10,8))

# Plot the bar plot

sns.barplot(x=avg_lead_time['hotel'],y=avg_lead_time['lead_time'],palette='copper')

# Set labels

plt.xlabel('Hotel')
plt.ylabel('Average_Lead_Time')
plt.title("Average Lead Time For Each Hotel Type")
# Out:
# Text(0.5, 1.0, 'Average Lead Time For Each Hotel Type')

# %% [markdown]
# #### **1. Why did you pick the specific chart?**

# %% [markdown]
# It shows the relationship using two axes, in which the **Average_lead_time** is on one axis and **Hotel** is on the other axis.

# %% [markdown]
# #### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# Average lead time is slightly longer in resort hotels. This means that guests plan their trips well in advance because resort hotels are far away from cities and are limited in number.

# %% [markdown]
# #### **3. Will the gained insights help creating a positive business impact?**
# ####**Are there any insights that lead to negative growth? Justify with specific reason.**

# %% [markdown]
# The gained insights will surely help in creating a positive business impact

# %% [markdown]
# #### **3) Which hotel has highest percentage of booking cancellation?**

# %% [markdown]
# ####**Chart - 3**

# %%
# Chart - 3 visualization code

# Bookings Canceled are indicated with "One" And Bookings Not Canceled are indicated with "Zero".

# Creating New DataFrame Where Bookings Are Canceled.

Canceled_Bookings = df1[df1['is_canceled']==1]
Canceled_Bookings = Canceled_Bookings.groupby('hotel').size().reset_index().rename(columns={0: "no_of_cancelled_bookings"})

# Adding New Colomn "total_bookings" for Calculating the Percentage of Bookings Canceled.

Canceled_Bookings['total_bookings'] = df1.groupby('hotel').size().reset_index().rename(columns={0:"total_bookings"}).drop('hotel',axis=1)

Canceled_Bookings
# Out:
#           hotel  no_of_cancelled_bookings  total_bookings
# 0    City Hotel                     16035           53274
# 1  Resort Hotel                      7974           33956

# %%
# Plotting the barplot

plt.figure(figsize=(10,8))
sns.barplot(x=Canceled_Bookings['hotel'],y=Canceled_Bookings['no_of_cancelled_bookings']*100/Canceled_Bookings['total_bookings'],palette='winter')

# Set labels

plt.xlabel('Hotel')
plt.ylabel('Percentage(%)')
plt.title("Percentage Of Booking Cancellation")
# Out:
# Text(0.5, 1.0, 'Percentage Of Booking Cancellation')

# %% [markdown]
# #### **1. Why did you pick the specific chart?**

# %% [markdown]
# It shows the relationship using two axes, in which the **Percentage(%)** is on one axis and **Hotel** is on the other axis.

# %% [markdown]
# #### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# Bookings in city hotels are often canceled due to a variety of factors. Many times, the cancellation is due to the customer's scheduling conflicts, such as a change in plans or an unforeseen event. Other times, it is due to economic factors, such as rising prices or a decrease in the customer's budget.
#
# In comparison, bookings at resort hotels are less likely to be canceled due to economic factors, as many resorts offer more value-added services and amenities. Furthermore, customers who book a resort hotel are often more likely to be traveling for leisure, which makes them less likely to cancel due to scheduling conflicts. However, resort bookings can still be canceled due to unforeseen events, such as natural disasters or illness.

# %% [markdown]
# #### **3. Will the gained insights help creating a positive business impact?**
# ####**Are there any insights that lead to negative growth? Justify with specific reason.**

# %% [markdown]
# The gained insights will surely help in creating a positive impact however the % of cancelled bookings for city hotel means the cost and other factors related to city hotel need to be improved.

# %% [markdown]
# ####**4) Which hotel has longer waiting time?**

# %% [markdown]
# ####**Chart - 4**

# %%
## Chart - 4 visualization code 

Waiting_Time_df = df1.groupby('hotel')['days_in_waiting_list'].mean().reset_index()
Waiting_Time_df
# Out:
#           hotel  days_in_waiting_list
# 0    City Hotel              1.020066
# 1  Resort Hotel              0.316763

# %%
sns.barplot(x=Waiting_Time_df['hotel'],y=Waiting_Time_df['days_in_waiting_list'],palette='Greens')
plt.xlabel('Hotel')
plt.ylabel('Avg_Waiting_Time')
plt.title('Waiting Time For Each Hotel Type')
# Out:
# Text(0.5, 1.0, 'Waiting Time For Each Hotel Type')

# %% [markdown]
# #### **1. Why did you pick the specific chart?**

# %% [markdown]
# It shows the relationship using two axes, in which the **Avg_waiting_time** is on one axis and **Hotel** is on the other axis.

# %% [markdown]
# #### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# Here city hotels have longer waiting period than resort hotels. Hence, it can be said that city hotels are more crowded than resort hotels.

# %% [markdown]
# #### **3. Will the gained insights help creating a positive business impact?**
# ####**Are there any insights that lead to negative growth? Justify with specific reason.**

# %% [markdown]
# The gained insights will surely help in creating a positive business impact.

# %% [markdown]
# ####**5) Which Hotels has the most repeated guests?**

# %% [markdown]
# ####**Chart - 5**

# %%
## Chart - 5 visualization code

# IN is_repeated_guest column "1" indicates "Reapeated Guest" & "0" indicates "Not A Repeated Guest"

repeated_guest_df = df1[df1['is_repeated_guest']==1].groupby('hotel').size().reset_index().rename(columns={0:'number_of_repeated_guests'})
repeated_guest_df
# Out:
#           hotel  number_of_repeated_guests
# 0    City Hotel                       1657
# 1  Resort Hotel                       1707

# %%
plt.figure(figsize=(10,8))
sns.barplot(x=repeated_guest_df['hotel'],y=repeated_guest_df['number_of_repeated_guests'],palette='PuBu')
plt.xlabel('Hotel')
plt.ylabel('Number_Of_Repeated_Guests_Count')
plt.title('Most Repeated Guests For Each Hotel Type')
# Out:
# Text(0.5, 1.0, 'Most Repeated Guests For Each Hotel Type')

# %% [markdown]
# ####**1. Why did you pick the specific chart?**

# %% [markdown]
# It shows the relationship using two axes, in which the **Number_of_repeated_guests** is on one axis and **Hotel** is on the other axis.

# %% [markdown]
# #### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# Resort hotels has slightly more repeated guests than city hotels, which is almost equal for both hotels.

# %% [markdown]
# #### **3. Will the gained insights help creating a positive business impact?**
# ####**Are there any insights that lead to negative growth? Justify with specific reason.**

# %% [markdown]
# The gained insights will surely help in creating a positive impact.

# %% [markdown]
# ####**6) Which hotel type has the highest ADR in different months?**

# %% [markdown]
# ####**Chart - 6**

# %%
## Chart - 6 visualization code

adr_in_diff_months = df1.groupby(['arrival_date_month','hotel'])['adr'].mean().reset_index()
adr_in_diff_months
# Out:
#    arrival_date_month         hotel         adr
# 0               April    City Hotel  117.314134
# 1               April  Resort Hotel   79.283805
# 2              August    City Hotel  125.148662
# 3              August  Resort Hotel  187.566659
# 4            December    City Hotel   93.204767
# 5            December  Resort Hotel   65.488671
# 6            February    City Hotel   89.266427
# 7            February  Resort Hotel   54.102809
# 8             January    City Hotel   85.269875
# 9             January  Resort Hotel   49.181693
# 10               July    City Hotel  120.318314
# 11               July  Resort Hotel  156.166914
# 12               June    City Hotel  123.996416
# 13               June  Resort Hotel  112.380859
# 14              March    City Hotel   95.193911
# 15              March  Resort Hotel   57.590889
# 16                May    City Hotel  128.055724
# 17                May  Resort Hotel   80.551101
# 18           November    City Hotel   89.882912
# ...

# %%
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
adr_in_diff_months['arrival_date_month'] = pd.Categorical(adr_in_diff_months['arrival_date_month'],categories =months,ordered = True)
adr_in_diff_months = adr_in_diff_months.sort_values('arrival_date_month')
adr_in_diff_months
# Out:
#    arrival_date_month         hotel         adr
# 8             January    City Hotel   85.269875
# 9             January  Resort Hotel   49.181693
# 6            February    City Hotel   89.266427
# 7            February  Resort Hotel   54.102809
# 15              March  Resort Hotel   57.590889
# 14              March    City Hotel   95.193911
# 0               April    City Hotel  117.314134
# 1               April  Resort Hotel   79.283805
# 17                May  Resort Hotel   80.551101
# 16                May    City Hotel  128.055724
# 13               June  Resort Hotel  112.380859
# 12               June    City Hotel  123.996416
# 11               July  Resort Hotel  156.166914
# 10               July    City Hotel  120.318314
# 3              August  Resort Hotel  187.566659
# 2              August    City Hotel  125.148662
# 22          September    City Hotel  118.764693
# 23          September  Resort Hotel  100.892331
# 20            October    City Hotel  107.585401
# ...

# %%
plt.figure(figsize=(20,8))
sns.lineplot(x=adr_in_diff_months['arrival_date_month'],y=adr_in_diff_months['adr'],linewidth=5,palette='winter',hue=adr_in_diff_months['hotel'])
plt.xlabel('Months')
plt.ylabel('Average_daily_rate(ADR)')
plt.title('ADR Across Each Month')
# Out:
# Text(0.5, 1.0, 'ADR Across Each Month')

# %% [markdown]
# ####**1. Why did you pick the specific chart?**

# %% [markdown]
# lineplot() function helps to represent the multi data variable relationships with a varying size of line to be plotted.

# %% [markdown]
# #### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# Here in June, July and August the adr value is higher for resort hotels as compared to city hotels. As guests are more interested in spending more time at resorts due to summer vacations, resort hotels generate more revenue during these months.

# %% [markdown]
# #### **3. Will the gained insights help creating a positive business impact?**
# ####**Are there any insights that lead to negative growth? Justify with specific reason.**

# %% [markdown]
# The gained insights will surely help in creating a positive business impact.

# %% [markdown]
# ####**7)Which distribution channel contributed more to adr in order to increase the the income.?**

# %% [markdown]
# ####**Chart - 7**

# %%
## Chart - 7 visualization code

distribution_channel_df=df1.groupby(['distribution_channel','hotel'])['adr'].mean().reset_index()
distribution_channel_df
# Out:
#   distribution_channel         hotel         adr
# 0            Corporate    City Hotel   83.777368
# 1            Corporate  Resort Hotel   53.036835
# 2               Direct    City Hotel  112.606688
# 3               Direct  Resort Hotel  106.566215
# 4                  GDS    City Hotel  120.317845
# 5                  GDS  Resort Hotel         NaN
# 6                TA/TO    City Hotel  112.663552
# 7                TA/TO  Resort Hotel  101.578317
# 8            Undefined    City Hotel   29.625000
# 9            Undefined  Resort Hotel  112.700000

# %%
plt.figure(figsize=(16,8))
sns.barplot(x='distribution_channel', y='adr', data=distribution_channel_df, hue='hotel',palette='summer')
plt.title('ADR Across Distribution channel For Each Hotel type')
# Out:
# Text(0.5, 1.0, 'ADR Across Distribution channel For Each Hotel type')

# %% [markdown]
# ####**1. Why did you pick the specific chart?**

# %% [markdown]
# It shows the relationship using two axes, in which the **adr** is on one axis and **distribution_channel** is on the other axis.

# %% [markdown]
# #### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# 1.'Direct' and 'TA/TO' contributed almost equally in both types of hotels i.e. 'City Hotel' and 'Resort Hotel'.
#
# 2.GDS has highly contributed in adr for 'City Hotel' type.
#
# 3.GDS needs to increase Resort Hotel bookings.

# %% [markdown]
# #### **3. Will the gained insights help creating a positive business impact?**
# ####**Are there any insights that lead to negative growth? Justify with specific reason.**

# %% [markdown]
# The gained insights will surely help in creating a positive business impact.

# %% [markdown]
# ####**8) Which distribution channel has the higest cancellation rate?**

# %% [markdown]
# ####**Chart - 8**

# %%
## Chart - 8 visualization code

# In "is_cancelled" column, "1" is indicated for cancellations of bookings.

list_of_bookings_cancelled = df1[df1['is_canceled']==1].groupby(['distribution_channel','hotel']).size().reset_index().rename(columns={0:'counts'})
list_of_bookings_cancelled
# Out:
#   distribution_channel         hotel  counts
# 0            Corporate    City Hotel     330
# 1            Corporate  Resort Hotel     316
# 2               Direct    City Hotel     971
# 3               Direct  Resort Hotel     952
# 4                  GDS    City Hotel      36
# 5                  GDS  Resort Hotel       0
# 6                TA/TO    City Hotel   14694
# 7                TA/TO  Resort Hotel    6706
# 8            Undefined    City Hotel       4
# 9            Undefined  Resort Hotel       0

# %%
# list_of_bookings_cancelled['percentage'] = list_of_bookings_cancelled['counts']*100/df1[df1['is_canceled']==1][0]

# list_of_bookings_cancelled['Indicator'] =  (list_of_bookings_cancelled['counts']/df1[df1['is_canceled']==1][0])*10

# Set plot size and plot barchart 

plt.figure(figsize=(20,8))
sns.barplot(x='distribution_channel',y='counts',hue="hotel",data=list_of_bookings_cancelled,palette='gray')

# Set labels

plt.xlabel('Distribution Channel')
plt.ylabel('Counts')
plt.title("List Of Bookings Cancelled By Distribution Channels For Each Hotel Type")
# Out:
# Text(0.5, 1.0, 'List Of Bookings Cancelled By Distribution Channels For Each Hotel Type')

# %% [markdown]
# ####**1. Why did you pick the specific chart?**

# %% [markdown]
# It shows the relationship using two axes, in which the **Counts** is on one axis and **Distribution Channel** is on the other axis.

# %% [markdown]
# #### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# 1.In "TA/TO", City hotels has the high cancellation rate compared to resort hotels.
#
# 2.In "Direct" both the hotels has almost same cancellation rate.

# %% [markdown]
# #### **3. Will the gained insights help creating a positive business impact?**
# ####**Are there any insights that lead to negative growth? Justify with specific reason.**

# %% [markdown]
# The gained insights will surely help in creating a positive business impact.

# %% [markdown]
# ####**9)Which Market Segment has the higest cancellation rate?**

# %% [markdown]
# ####**Chart - 9**

# %%
## Chart - 9 visualization code

market_segment_df = df1[df1['is_canceled']==1].groupby(['market_segment','hotel']).size().reset_index().rename(columns={0:'counts'})
market_segment_df
# Out:
#    market_segment         hotel  counts
# 0        Aviation    City Hotel      45
# 1        Aviation  Resort Hotel       0
# 2   Complementary    City Hotel      54
# 3   Complementary  Resort Hotel      31
# 4       Corporate    City Hotel     263
# 5       Corporate  Resort Hotel     246
# 6          Direct    City Hotel     912
# 7          Direct  Resort Hotel     825
# 8          Groups    City Hotel     887
# 9          Groups  Resort Hotel     445
# 10  Offline TA/TO    City Hotel    1257
# 11  Offline TA/TO  Resort Hotel     800
# 12      Online TA    City Hotel   12615
# 13      Online TA  Resort Hotel    5627
# 14      Undefined    City Hotel       2
# 15      Undefined  Resort Hotel       0

# %%
## Visualizing the data

plt.figure(figsize=(20,8))
sns.barplot(x='market_segment',y='counts',hue="hotel",data= market_segment_df,palette='winter')

plt.xlabel('market_segment')
plt.ylabel('Counts')
plt.title('Cancellation Rate Of Each Market Segment For Hotel Types')
# Out:
# Text(0.5, 1.0, 'Cancellation Rate Of Each Market Segment For Hotel Types')

# %% [markdown]
# ####**1. Why did you pick the specific chart?**

# %% [markdown]
# It shows the relationship using two axes, in which the **Counts** is on one axis and **Distribution Channel** is on the other axis.

# %% [markdown]
# #### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# 1. 'Online T/A' has the highest cancellation in both type of cities.
#
# 2. To reduce booking cancellations hotels should follow up their guests regularly and inform them about the exciting services offered by hotels for free and hotels should provide some discount coupons to their guests. Share how regular guests enjoyed their precious time at your hotel.

# %% [markdown]
# #### **3. Will the gained insights help creating a positive business impact?**
# ####**Are there any insights that lead to negative growth? Justify with specific reason.**

# %% [markdown]
# The gained insights will surely help in creating a positive business impact.

# %% [markdown]
# ####**10) ADR across different market segment.?**

# %% [markdown]
# ####**Chart - 10**

# %%
## Chart - 10 visualization code

data = df1.groupby(['market_segment','hotel','is_canceled'])['adr'].mean().reset_index()
data
# Out:
#    market_segment         hotel  is_canceled         adr
# 0        Aviation    City Hotel            0  100.630829
# 1        Aviation    City Hotel            1  100.544444
# 2        Aviation  Resort Hotel            0         NaN
# 3        Aviation  Resort Hotel            1         NaN
# 4   Complementary    City Hotel            0    2.875501
# 5   Complementary    City Hotel            1    2.191296
# 6   Complementary  Resort Hotel            0    4.390127
# 7   Complementary  Resort Hotel            1    1.209677
# 8       Corporate    City Hotel            0   82.079575
# 9       Corporate    City Hotel            1   90.012586
# 10      Corporate  Resort Hotel            0   49.569977
# 11      Corporate  Resort Hotel            1   68.510935
# 12         Direct    City Hotel            0  120.829624
# 13         Direct    City Hotel            1  123.343936
# 14         Direct  Resort Hotel            0  110.152088
# ...

# %%
## Visualizing the data 

plt.figure(figsize=(18,6))
sns.barplot(x='market_segment',y='adr',hue='hotel',data=data.sort_values('adr',ascending=False),palette='BuGn')
plt.title('ADR Across Market Segment')
# Out:
# Text(0.5, 1.0, 'ADR Across Market Segment')

# %% [markdown]
# ####**1. Why did you pick the specific chart?**

# %% [markdown]
# It shows the relationship using two axes, in which the **adr** is on one axis and **market_segment** is on the other axis.

# %% [markdown]
# #### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# 1. 'Direct' and 'Online TA' contribute the most in both types of hotels.
#
# 2. The aviation department should focus on increasing 'city hotel' bookings.

# %% [markdown]
# #### **3. Will the gained insights help creating a positive business impact?**
# ####**Are there any insights that lead to negative growth? Justify with specific reason.**

# %% [markdown]
# The gained insights will surely help in creating a positive business impact.

# %% [markdown]
# #### **Chart - 15 - Correlation Heatmap**

# %%
# Correlation Heatmap visualization code

plt.figure(figsize=(18,10))
sns.heatmap(df1.corr(),annot=True)
plt.title('Correlation of the columns')
# Out:
# Text(0.5, 1.0, 'Correlation of the columns')

# %% [markdown]
# ### **1. Why did you pick the specific chart?**

# %% [markdown]
# Correlation heatmaps are used to understand which variables are related to each other and the strength of this relationship.

# %% [markdown]
# ### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# 1) "is_cancelled" and "same_room_alloted_or_not" are negatively correlated. That means customer is unlikely to cancel his bookings if he don't get the same room as per reserved room. We have visualized it above.
#
# 2) "lead_time" and "total_stays" is positively correlated.That means more is the stay of customer more will be the lead time.
#
# 3)adults,childrens and babies are correlated to each other. That means more the people more will be adr.
#
# 4) "is_repeated guest" and "previous bookings not cancelled" has strong correlation. may be repeated guests are not more likely to cancel their bookings.
#
# 5."adr" and "total_number_of_people" are positively correlated, so if people increase, ADR will automatically increase which means hotels can earn huge revenue.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?

# %% [markdown]
# 1. Set Non-refundable Rates, Collect deposits, and implement more rigid cancellation policies.
#
# 2. Using Advanced Purchase Rates with varying Lead Time windows.
#
# 3. Encourage Direct bookings by offering special discounts.
#
# 4. Hotels should consider the total number of special requests from guests to reduce the possibility of cancellations by improving customer service.
#
# 5. Monitor where the cancellations are coming from such as Market Segment, distribution channels, etc.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# 1. City hotels are the most preferred hotel type by the guests.
#
# 2. 27.5 % bookings were got cancelled out of all the bookings.
#
# 3. Only 3.9 % people were revisited the hotels. Rest 96.1 % were new guests. Thus retention rate is low.
#
# 4. Most of the customers (91.6%) do not require car parking spaces.
#
# 5. 79.1 % bookings were made through TA/TO (travel agents/Tour operators).
#
# 6. BB( Bed & Breakfast) is the most preferred type of meal by the guests.
#
# 7. Maximum number of guests were from Portugal, i.e. more than 25000 guests.
#
# 8. Most of the bookings for City hotels and Resort hotel were happened in 2016.
#
# 9. Average ADR for city hotel is high as compared to resort hotels. These City hotels are generating more revenue than the resort hotels.
#
# 10. Booking cancellation rate is high for City hotels which almost 30 %.
#
# 11. Average lead time for resort hotel is high.
#
# 12. Waiting time period for City hotel is high as compared to resort hotels. That means city hotels are much busier than Resort hotels.
#
# 13. Resort hotels have the most repeated guests.
#
# 14. Almost 19 % people did not cancel their bookings even after not getting the same room which they reserved while booking hotel. Only 2.5 % people cancelled the booking.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
